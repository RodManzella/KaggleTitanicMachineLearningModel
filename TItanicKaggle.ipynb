# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Creating dataframes

# %%
gender_sub_path = r'C:\datasets\titanickaggle\gender_submission.csv'
test_path = r'C:\datasets\titanickaggle\test.csv'
train_path = r'C:\datasets\titanickaggle\train.csv'

gender_submission_df = pd.read_csv(gender_sub_path)
test_df = pd.read_csv(test_path)
train_df = pd.read_csv(train_path)

# %% [markdown]
# # Checking each head of the dataframes

# %% [markdown]
# ## gender submission dataframe

# %%
gender_submission_df.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %% [markdown]
# ## test dataframe

# %%
test_df.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %% [markdown]
# ## train dataframe

# %%
train_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # Creating a dataframe with only people who did not survive

# %%
did_not_survive = train_df.loc[train_df['Survived'] == 0] 
did_not_survive
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# # Creating a dataframe with only people who did survive

# %%
did_survive = train_df.loc[train_df['Survived'] == 1] 
did_survive
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# # How many minors did survive/did not

# %% [markdown]
# ## survived(Minors)

# %%
did_survive.loc[did_survive['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 9             10         1       2       Nasser, Mrs. Nicholas (Adele Achem)
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 22            23         1       3               McGowan, Miss. Anna "Annie"
# 39            40         1       3               Nicola-Yarred, Miss. Jamila
# 43            44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# ..           ...       ...     ...                                       ...
# 830          831         1       3   Yasbeck, Mrs. Antoni (Selini Alexander)
# 831          832         1       2           Richards, Master. George Sibley
# 853          854         1       1                 Lines, Miss. Mary Conover
# 869          870         1       3           Johnson, Master. Harold Theodor
# 875          876         1       3          Najib, Miss. Adele Kiamie "Jane"
#
# ...

# %%
did_survive.loc[did_survive['Age'] < 18].describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    61.000000      61.0  61.000000  61.000000  61.000000  61.000000
# mean    441.442623       1.0   2.295082   7.888033   0.770492   1.032787
# std     275.826124       0.0   0.760357   6.129831   0.972856   0.752046
# min      10.000000       1.0   1.000000   0.420000   0.000000   0.000000
# 25%     194.000000       1.0   2.000000   3.000000   0.000000   0.000000
# 50%     446.000000       1.0   2.000000   5.000000   1.000000   1.000000
# 75%     721.000000       1.0   3.000000  15.000000   1.000000   2.000000
# max     876.000000       1.0   3.000000  17.000000   4.000000   2.000000
#
#              Fare
# count   61.000000
# mean    34.857310
# std     39.301839
# min      7.225000
# 25%     12.475000
# 50%     20.525000
# 75%     36.750000
# max    211.337500

# %%
did_survive.loc[did_survive['Age'] < 18, 'Age'].value_counts()
# Out:
# Age
# 4.00     7
# 16.00    6
# 17.00    6
# 1.00     5
# 3.00     5
# 15.00    4
# 5.00     4
# 2.00     3
# 14.00    3
# 9.00     2
# 8.00     2
# 0.83     2
# 13.00    2
# 0.75     2
# 6.00     2
# 12.00    1
# 0.92     1
# 7.00     1
# 0.67     1
# 11.00    1
# 0.42     1
# Name: count, dtype: int64

# %% [markdown]
# ### 61 minors survived
# ##

# %% [markdown]
# ## died(minors)

# %%
did_not_survive.loc[did_not_survive['Age'] < 18]
# Out:
#      PassengerId  Survived  Pclass                                     Name  \
# 7              8         0       3           Palsson, Master. Gosta Leonard
# 14            15         0       3     Vestrom, Miss. Hulda Amanda Adolfina
# 16            17         0       3                     Rice, Master. Eugene
# 24            25         0       3            Palsson, Miss. Torborg Danira
# 50            51         0       3               Panula, Master. Juha Niilo
# 59            60         0       3       Goodwin, Master. William Frederick
# 63            64         0       3                    Skoog, Master. Harald
# 71            72         0       3               Goodwin, Miss. Lillian Amy
# 86            87         0       3                   Ford, Mr. William Neal
# 111          112         0       3                     Zabour, Miss. Hileni
# 114          115         0       3                    Attalah, Miss. Malake
# ...

# %%
did_not_survive.loc[did_not_survive['Age'] < 18].describe()
# Out:
#        PassengerId  Survived     Pclass        Age      SibSp      Parch  \
# count    52.000000      52.0  52.000000  52.000000  52.000000  52.000000
# mean    414.865385       0.0   2.923077  10.394231   2.269231   1.076923
# std     290.566791       0.0   0.334087   5.674450   1.858899   0.859689
# min       8.000000       0.0   1.000000   1.000000   0.000000   0.000000
# 25%     145.750000       0.0   3.000000   5.500000   0.000000   0.000000
# 50%     381.000000       0.0   3.000000  10.500000   3.000000   1.000000
# 75%     695.750000       0.0   3.000000  16.000000   4.000000   2.000000
# max     853.000000       0.0   3.000000  17.000000   5.000000   3.000000
#
#              Fare
# count   52.000000
# mean    26.954890
# std     21.759124
# min      7.054200
# 25%     10.490625
# 50%     27.900000
# 75%     32.134375
# max    151.550000

# %%
did_not_survive.loc[did_not_survive['Age'] < 18, 'Age'].value_counts()
# Out:
# Age
# 16.0    11
# 2.0      7
# 17.0     7
# 9.0      6
# 14.0     3
# 11.0     3
# 4.0      3
# 8.0      2
# 7.0      2
# 1.0      2
# 10.0     2
# 14.5     1
# 15.0     1
# 3.0      1
# 6.0      1
# Name: count, dtype: int64

# %% [markdown]
# ## total number of minors = 113
# ## 61 survived, 52 died

# %% [markdown]
# ##
# ##

# %% [markdown]
# # Analysis based on age

# %% [markdown]
# ## Histogram of people who survived based on age

# %%
plt.hist(did_survive['Age'], bins=50, edgecolor='black')  # 'bins' define o número de barras no histograma
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age histogram')
plt.grid(True)

# Exibir o gráfico
plt.show()

# %% [markdown]
# ## Histogram of people who died based on age

# %%
plt.hist(did_not_survive['Age'], bins=50, edgecolor='black')  # 'bins' define o número de barras no histograma
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age histogram')
plt.grid(True)

# Exibir o gráfico
plt.show()
